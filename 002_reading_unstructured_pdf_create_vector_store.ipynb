# %%
#!pip install tiktoken==0.6.0 pypdf==4.0.1 langchain==0.1.1 langchain-community==0.0.13 chromadb==0.4.22 sentence-transformers==3.0.1

# %%
import chromadb
persistance_directory = 'vectorstore'
chroma_client = chromadb.PersistentClient(persistance_directory)

# %%
# Run this code only once to create the base empty SQLite db file. This storing of Embeddings .

import sqlite3
import os

# Create a new SQLite database file
db_path = f"{persistance_directory}/chroma.sqlite3"

expand_db = False # make it True and execute it first time.

if not expand_db:
    pass  # Do nothing
else:
    conn = sqlite3.connect(db_path)

    # Create a table named 'temp' and insert 5 numbers into it
    conn.execute("CREATE TABLE IF NOT EXISTS temp (id INTEGER PRIMARY KEY, number INTEGER);")

    # Insert 5 numbers into the 'temp' table
    numbers_to_insert = [1, 2, 3, 4, 5]
    conn.executemany("INSERT INTO temp (number) VALUES (?);", [(num,) for num in numbers_to_insert])

    # Commit changes and close the connection
    conn.commit()
    conn.close()

    # Manually expand the file to XX MB
    initial_size_mb = 1900
    with open(db_path, "ab") as f:
        f.truncate(initial_size_mb * 1024 * 1024)  # Set the file size to XX MB

    # re-initializing
    conn = sqlite3.connect(db_path)
    # Create a table named 'temp' and insert 5 numbers into it
    conn.execute("DROP TABLE IF EXISTS temp;")

    # Commit changes and close the connection
    conn.commit()
    conn.close()

# %%
chroma_client.list_collections()
# Out:
# [Collection(name=my_collection)]

# %%
if "my_collection" in [col.name for col in chroma_client.list_collections()]:
    chroma_client.delete_collection(name="my_collection")  # Deletes the entire collection

# Recreate the collection
collection = chroma_client.get_or_create_collection(name="my_collection")

# %%
import os
from pathlib import Path
# from langchain.text_splitter import CharacterTextSplitter  # Importing text splitter
from langchain.text_splitter import RecursiveCharacterTextSplitter # Importing a better text splitter!

# Define the path to your directory containing the text files
directory_path = Path("document-corpus")

# Initialize lists for documents, IDs, and metadata
documents = []
ids = []
metadatas = []

# %%
import re

def filter_text(text):
    """
    Replaces multiple new lines with a single space and strips extra whitespace.
    
    Parameters:
    - text (str): The text to filter.
    
    Returns:
    - str: The filtered text.
    """
    text = re.sub(r'\n+', ' ', text)  # Replace multiple new lines with a single space
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text.strip()  # Strip leading and trailing whitespace

# %%
# # Initialize lists for documents, IDs, and metadata
# xdocuments = []
# xids = []
# xmetadatas = []

# from PyPDF2 import PdfReader

# # Initialize the text splitter with the desired chunk size and overlap
# # Splitting Logic: The CharacterTextSplitter splits text based on a fixed character length. It does this without considering the semantic structure of the text.
# # text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=100, separator='')

# # Splitting Logic: The RecursiveCharacterTextSplitter attempts to split text into chunks of a given length, but with a focus on preserving the semantic integrity of the text.
# text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
#     encoding_name='cl100k_base',
#     chunk_size=512,
#     chunk_overlap=32
# )

# # Loop through each PDF file in the directory
# for file in directory_path.glob("*.pdf"):  # Only select .pdf files
#     try:
#         print(f"Processing file: {file}")  # Debugging line to track files
#         with open(file, "rb") as f:
#             # Read the PDF content
#             pdf_reader = PdfReader(f)
#             content = ""
#             for page in pdf_reader.pages:
#                 content += page.extract_text() or ""
#             content = filter_text(content)  # Stripping extra whitespace/newlines
            
#             if content:  # Only process non-empty files
#                 # Use the text splitter to split the document into chunks
#                 chunks = text_splitter.split_text(content)
#                 print("chunks", len(chunks), " file name", file)
#                 # Append each chunk as a document
#                 for i, chunk in enumerate(chunks):
#                     xdocuments.append(chunk)
#                     # Create unique IDs for each chunk (using file stem and chunk index)
#                     xids.append(f"{file.stem}_chunk_{i}")
#                     print(f"Added document chunk with ID: {file.stem}_chunk_{i}")
                    
#                     # Create metadata for the document chunk
#                     metadata = {
#                         "filename": file.name,
#                         "size": len(chunk),  # Size of the chunk in characters
#                         "path": str(file),
#                         "chunk_index": i  # Index of the chunk
#                     }
#                     xmetadatas.append(metadata)
#             else:
#                 print(f"Skipped empty file: {file}")
#     except Exception as e:
#         print(f"Error reading {file}: {e}")
#         continue

# %%
# from PyPDF2 import PdfReader
# from sentence_splitter import SentenceSplitter

# # Initialize the sentence splitter for your target language
# sentence_splitter = SentenceSplitter(language='en')  # Adjust the language as needed

# # Function to split text into sentences
# def split_into_sentences(content):
#     # Split content into sentences
#     sentences = sentence_splitter.split(text=content)
#     return sentences

# # Process PDF files in the directory
# for file in directory_path.glob("*.pdf"):  # Only select .pdf files
#     try:
#         print(f"Processing file: {file}")  # Debugging line to track files
#         with open(file, "rb") as f:
#             # Read the PDF content
#             pdf_reader = PdfReader(f)
#             content = ""
#             for page in pdf_reader.pages:
#                 content += page.extract_text() or ""
#             content = filter_text(content)  # Stripping extra whitespace/newlines
            
#             if content:  # Only process non-empty files
#                 # Use the sentence splitter to split text
#                 sentences = split_into_sentences(content)
#                 print("Sentences:", len(sentences), "File name:", file)
                
#                 # Append each sentence as a document
#                 for i, sentence in enumerate(sentences):
#                     documents.append(sentence)
#                     # Create unique IDs for each sentence (using file stem and sentence index)
#                     ids.append(f"{file.stem}_sentence_{i}")
#                     # print(f"Added document sentence with ID: {file.stem}_sentence_{i}")
                    
#                     # Create metadata for the sentence
#                     metadata = {
#                         "filename": file.name,
#                         "size": len(sentence),  # Size of the sentence in characters
#                         "path": str(file),
#                         "sentence_index": i  # Index of the sentence
#                     }
#                     metadatas.append(metadata)
#             else:
#                 print(f"Skipped empty file: {file}")
#     except Exception as e:
#         print(f"Error reading {file}: {e}")
#         continue

# %%
from PyPDF2 import PdfReader
from sentence_splitter import SentenceSplitter

# Splitting Logic: The RecursiveCharacterTextSplitter attempts to split text into chunks of a given length, but with a focus on preserving the semantic integrity of the text.
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name='cl100k_base',
    chunk_size=1024,
    chunk_overlap=32
)

# Process PDF files in the directory
for file in directory_path.glob("*.pdf"):  # Only select .pdf files
    try:
        print(f"Processing file: {file}")  # Debugging line to track files
        with open(file, "rb") as f:
            # Read the PDF content
            pdf_reader = PdfReader(f)
            content = ""
            for page in pdf_reader.pages:
                content += page.extract_text() or ""
            content = filter_text(content)  # Stripping extra whitespace/newlines
            
            if content:  # Only process non-empty files
                # Use the recursive splitter to split text into text sections that has multiple sentences similar to a paragraph.
                sections = text_splitter.split_text(content)
                print("sections:", len(sections), "File name:", file)
                
                # Append each sentence as a document
                for i, text_section in enumerate(sections):
                    documents.append(text_section)
                    # Create unique IDs for each text_section (using file stem and text_section index)
                    ids.append(f"{file.stem}_section_{i}")
                    # print(f"Added document text_section with ID: {file.stem}_sentence_{i}")
                    
                    # Create metadata for the text_section
                    metadata = {
                        "filename": file.name,
                        "size": len(text_section),  # Size of the text_section in characters
                        "path": str(file),
                        "sentence_index": i  # Index of the text_section
                    }
                    metadatas.append(metadata)
            else:
                print(f"Skipped empty file: {file}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
        continue
# Out:
# Processing file: document-corpus\Additive_Manufacturing_of_Bio_and_Synthetic_Polymers.pdf
# sections: 280 File name: document-corpus\Additive_Manufacturing_of_Bio_and_Synthetic_Polymers.pdf
# Processing file: document-corpus\Advanced_BiopolymerBased_Nanocomposites_and_Hybrid_Materials.pdf
# sections: 89 File name: document-corpus\Advanced_BiopolymerBased_Nanocomposites_and_Hybrid_Materials.pdf
# Processing file: document-corpus\Advanced_Ecofriendly_WoodBased_Composites.pdf
# sections: 210 File name: document-corpus\Advanced_Ecofriendly_WoodBased_Composites.pdf
# Processing file: document-corpus\Advanced_Flame_Retardant_Materials.pdf
# sections: 141 File name: document-corpus\Advanced_Flame_Retardant_Materials.pdf
# Processing file: document-corpus\Advanced_Thermoplastic_Polymers_and_Composites.pdf
# sections: 499 File name: document-corpus\Advanced_Thermoplastic_Polymers_and_Composites.pdf
# Processing file: document-corpus\Advances_and_Applications_of_Block_Copolymers.pdf
# sections: 390 File name: document-corpus\Advances_and_Applications_of_Block_Copolymers.pdf
# Processing file: document-corpus\Advances_in_BioBased_and_Biodegradable_Polymeric_Composites.pdf
# sections: 616 File name: document-corpus\Advances_in_BioBased_and_Biodegradable_Polymeric_Composites.pdf
# Processing file: document-corpus\Advances_in_Elastomers.pdf
# sections: 112 File name: document-corpus\Advances_in_Elastomers.pdf
# Processing file: document-corpus\Advances_in_Functional_Rubber_and_Elastomer_Composites.pdf
# sections: 269 File name: document-corpus\Advances_in_Functional_Rubber_and_Elastomer_Composites.pdf
# Processing file: document-corpus\Advances_in_Manufacturing_and_Characterization_of_Functional_Polyesters.pdf
# sections: 231 File name: document-corpus\Advances_in_Manufacturing_and_Characterization_of_Functional_Polyesters.pdf
# Processing file: document-corpus\Advances_in_Sustainable_Concrete_System.pdf
# unknown widths :
# [0, IndirectObject(5842, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5846, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5850, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5854, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5859, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5863, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5871, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5875, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5854, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5880, 0, 2545093682992)]
# unknown widths :
# [0, IndirectObject(5884, 0, 2545093682992)]
# sections: 406 File name: document-corpus\Advances_in_Sustainable_Concrete_System.pdf
# Processing file: document-corpus\Advances_in_Sustainable_Polymeric_Materials.pdf
# sections: 612 File name: document-corpus\Advances_in_Sustainable_Polymeric_Materials.pdf
# Processing file: document-corpus\Advances_in_Sustainable_Polymeric_Materials_II.pdf
# sections: 369 File name: document-corpus\Advances_in_Sustainable_Polymeric_Materials_II.pdf
# sections: 258 File name: document-corpus\Synthesis_and_Applications_of_Biopolymer_Composites.pdf
# Processing file: document-corpus\Synthesis_Characterization_and_Application_of_Hybrid_Composites.pdf
# sections: 149 File name: document-corpus\Synthesis_Characterization_and_Application_of_Hybrid_Composites.pdf
# Processing file: document-corpus\Synthesis_Processing_Structure_and_Properties_of_Polymer_Materials.pdf
# sections: 505 File name: document-corpus\Synthesis_Processing_Structure_and_Properties_of_Polymer_Materials.pdf
# Processing file: document-corpus\Thermal_Analysis_Kinetics_for_Understanding_Materials_Behavior.pdf
# sections: 175 File name: document-corpus\Thermal_Analysis_Kinetics_for_Understanding_Materials_Behavior.pdf

# %%
print(len(documents))
print(len(ids))
print(len(metadatas))
# Out:
# 15646
# 15646
# 15646

# %%
print((documents[0]))
print((ids[0]))
print((metadatas[0]))
# Out:
# Edited byAdditive Manufacturing of Bio and Synthetic Polymers Emin Bayraktar, S. M. Sapuan and R. A. Ilyas Printed Edition of the Special Issue Published in Polymers www.mdpi.com/journal/polymersAdditive Manufacturing of Bio and Synthetic PolymersAdditive Manufacturing of Bio and Synthetic Polymers Editors Emin Bayraktar S. M. Sapuan R. A. Ilyas MDPI•Basel•Beijing•Wuhan•Barcelona •Belgrade •Manchester •Tokyo•Cluj•Tianjin Editors Emin Bayraktar Mechanical and Manufacturing Engineering School ISAE-Supmeca-Paris Saint-Ouen FranceS. M. Sapuan Department of Mechanical and Manufacturing Engineering, Faculty of Engineering Universiti Putra Malaysia Serdang, Selangor MalaysiaR. A. Ilyas School of Chemical and Energy Engineering, Faculty of Engineering Universiti Teknologi Malaysia Skudai Malaysia Editorial Ofﬁce MDPI St. Alban-Anlage 66 4052 Basel, Switzerland This is a reprint of articles from the Special Issue published online in the open access journal Polymers (ISSN 2073-4360) (available at: www.mdpi.com/journal/polymers/special issues/ additive manufacturing ofbioand synthetic polymers). For citation purposes, cite each article independently as indicated on the article page online and as indicated below: LastName, A.A.; LastName, B.B.; LastName, C.C. Article Title. Journal Name Year ,Volume Number , Page Range. ISBN 978-3-0365-3320-9 (Hbk) ISBN 978-3-0365-3319-3 (PDF) © 2022 by the authors. Articles in this book are Open Access and distributed under the Creative Commons Attribution (CC BY) license, which allows users to download, copy and build upon published articles, as long as the author and publisher are properly credited, which ensures maximum dissemination and a wider impact of our publications. The book as a whole is distributed by MDPI under the terms and conditions of the Creative Commons license CC BY-NC-ND.Contents About the Editors . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . vii Preface to ”Additive Manufacturing of Bio and Synthetic Polymers” . . . . . . . . . . . . . . . ix R.A. Ilyas, S.M. Sapuan, M.M. Harussani, M.Y.A.Y. Hakimi, M.Z.M. Haziq and M.S.N. Atikah et al. Polylactic Acid (PLA) Biocomposite: Processing, Additive Manufacturing and Advanced Applications Reprinted from: Polymers 2021 ,13, 1326, doi:10.3390/polym13081326 . . . . . . . . . . . . . . . . 1 Waleed Ahmed, Sidra Siraj and Ali H. Al-Marzouqi Embracing Additive Manufacturing Technology through Fused Filament Fabrication for Antimicrobial with Enhanced Formulated Materials Reprinted from: Polymers 2021 ,13, 1523, doi:10.3390/polym13091523 . . . . . . . . . . . . . . . . 35 Aida Haryati Jamadi, Nadlene Razali, Michal Petr ˚ u, Mastura Mohammad Taha, Noryani Muhammad and Rushdan Ahmad Ilyas Effect of Chemically Treated Kenaf Fibre on Mechanical and Thermal Properties of PLA Composites Prepared through Fused Deposition Modeling (FDM) Reprinted from: Polymers 2021 ,13, 3299, doi:10.3390/polym13193299 . . . . . . . . . . . . . . . . 55 Richard Kuracina, Zuzana Szabov´ a, Eva Buransk´ a, Alica Pastierov´ a, Peter Gogola and Ivan Buransk ´y Determination of Fire Parameters of Polyamide 12 Powder for Additive Technologies Reprinted from: Polymers 2021 ,13, 3014, doi:10.3390/polym13173014 . . . . . . . . . . . . . . . . 75 Victor Beloshenko, Yan Beygelzimer, Vyacheslav Chishko, Bogdan Savchenko, Nadiya Sova and Dmytro Verbylo et al. Mechanical Properties of Flexible TPU-Based 3D Printed Lattice Structures: Role of Lattice Cut Direction and Architecture Reprinted from: Polymers 2021 ,13, 2986,
# Additive_Manufacturing_of_Bio_and_Synthetic_Polymers_section_0
# {'filename': 'Additive_Manufacturing_of_Bio_and_Synthetic_Polymers.pdf', 'size': 3573, 'path': 'document-corpus\\Additive_Manufacturing_of_Bio_and_Synthetic_Polymers.pdf', 'sentence_index': 0}

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_community.embeddings.sentence_transformer import (SentenceTransformerEmbeddings)
from sentence_transformers import SentenceTransformer


# Initialize embedding model
#  Ideal when you want flexibility with different models, compatibility with Hugging Face ecosystems, or are working on applications where model speed and memory efficiency are crucial.
# embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2") 

# When accuracy and precision are more important, and you have more computational resources available, gte-large provides richer, more nuanced embeddings at the cost of being slower and more resource-intensive.
try:
    # Load tokenizer for preprocessing text
    #embedding_model = SentenceTransformerEmbeddings(model_name="dunzhang/stella_en_1.5B_v5")
    # embedding_model = SentenceTransformer("dunzhang/stella_en_1.5B_v5", trust_remote_code=True).cuda()
    # embedding_model = SentenceTransformerEmbeddings(
    #     model_name="dunzhang/stella_en_1.5B_v5", device="cuda"
    # )
    embedding_model = HuggingFaceEmbeddings(model_name="dunzhang/stella_en_1.5B_v5", model_kwargs={'device':'cuda'})

except Exception as e:
    print(f"Error loading tokenizer or embeddings: {e}")
    print("Defaulting to sentence-transformers/all-MiniLM-L6-v2.")
    embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")


# Create the initial vector store with an empty collection
vectorstore = Chroma(
    collection_name="my_collection",
    embedding_function=embedding_model,
    persist_directory=persistance_directory  # Adjust if using persistent storage
)

# Define a function to add in batches
def add_documents_in_batches(vectorstore, documents, ids, metadatas, batch_size=10000):
    total_docs = len(documents)
    print(f"total_docs: {total_docs}")
    batch_counter = 1
    for start_idx in range(0, total_docs, batch_size):
        end_idx = min(start_idx + batch_size, total_docs)
        batch_documents = documents[start_idx:end_idx]
        batch_ids = ids[start_idx:end_idx]
        batch_metadatas = metadatas[start_idx:end_idx]
        print(f"start_idx: {start_idx}, end_idx: {end_idx}")

        # Add documents to the ChromaDB collection using the embeddings
        vectorstore.add_texts(
            texts=batch_documents,
            metadatas=batch_metadatas,
            ids=batch_ids
        )
        
        print(f"Added batch #{batch_counter} from {start_idx} to {end_idx}.")
        batch_counter += 1

# Check if any documents were collected before adding to the collection
if len(documents) == len(ids) and documents:
    # Add documents in batches
    add_documents_in_batches(vectorstore, documents, ids, metadatas)
    print(f"Added {len(documents)} document chunks to the collection with metadata.")
    vectorstore.persist()  # Persist the collection to disk if using a persistent directory
else:
    print("Mismatch in documents and ids or no documents were collected.")
# Out:
# c:\Users\babu.ai\.conda\envs\env390-gpu\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# total_docs: 15646
# start_idx: 0, end_idx: 10000
# Added batch #1 from 0 to 10000.
# start_idx: 10000, end_idx: 15646
# Added batch #2 from 10000 to 15646.
# Added 15646 document chunks to the collection with metadata.

# %%
# from langchain.vectorstores import Chroma
# from langchain.embeddings.huggingface import HuggingFaceEmbeddings
# from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
# from transformers import AutoTokenizer

# # Initialize tokenizer for LLaMA-compatible processing
# tokenizer_name = "meta-llama/Llama-3.2-3B"

# try:
#     # Load tokenizer for preprocessing text
#     tokenizer = AutoTokenizer.from_pretrained(tokenizer_name, use_auth_token="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")
#     embedding_model = SentenceTransformerEmbeddings(model_name="thenlper/gte-large")
# except Exception as e:
#     print(f"Error loading tokenizer or embeddings: {e}")
#     print("Defaulting to sentence-transformers/all-MiniLM-L6-v2.")
#     embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# # Initialize the vector store
# vectorstore = Chroma(
#     collection_name="my_collection",
#     embedding_function=embedding_model,
#     persist_directory=persistance_directory  # Adjust for persistent storage
# )

# # Define a function to preprocess text using the tokenizer
# def preprocess_documents(documents, tokenizer):
#     tokenized_documents = []
#     for doc in documents:
#         if not isinstance(doc, str):
#             # print(f"Skipping non-string document: {doc}")
#             continue
#         # Tokenize text and decode back to text, ensuring consistent processing
#         tokens = tokenizer(doc, truncation=True, padding="longest", return_tensors="pt")  # Tokenize text
#         tokenized_text = tokenizer.decode(tokens["input_ids"][0], skip_special_tokens=True)  # Convert back to string
#         tokenized_documents.append(tokenized_text)
#     return tokenized_documents

# # Function to add documents in batches
# def add_documents_in_batches(vectorstore, documents, ids, metadatas, batch_size=10000):
#     total_docs = len(documents)
#     print(f"Total documents to add: {total_docs}")
#     batch_counter = 1
#     for start_idx in range(0, total_docs, batch_size):
#         end_idx = min(start_idx + batch_size, total_docs)
#         batch_documents = documents[start_idx:end_idx]
#         batch_ids = ids[start_idx:end_idx]
#         batch_metadatas = metadatas[start_idx:end_idx]
#         print(f"Processing batch from index {start_idx} to {end_idx}.")

#         # Add documents to the ChromaDB collection
#         vectorstore.add_texts(
#             texts=batch_documents,
#             metadatas=batch_metadatas,
#             ids=batch_ids
#         )
        
#         print(f"Batch #{batch_counter} added successfully.")
#         batch_counter += 1

# # Ensure documents and IDs are aligned before adding to the vector store
# if len(documents) == len(ids) and documents:
#     # Preprocess documents with tokenizer
#     tokenized_documents = preprocess_documents(documents, tokenizer)
#     print("tk_    ",tokenized_documents)
#     # Add preprocessed documents in batches to the collection
#     #add_documents_in_batches(vectorstore, tokenized_documents, ids, metadatas)
#     #print(f"Added {len(tokenized_documents)} document chunks to the collection with metadata.")
#     #vectorstore.persist()  # Persist the collection if a persistent directory is used
# else:
#     print("Error: Mismatch between documents and IDs, or no documents to process.")

# %%
vectorstore.persist()

# %%
# all_docs = collection.get()
# all_docs

# %%
# results = collection.query(
#     query_texts=["Biosynthesis"],
#     n_results = 2
# )
# results
